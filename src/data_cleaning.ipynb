# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
import data_reader
import pandas
import time
import numpy as np

# %%
features = pandas.read_csv('../data/Cleaned/features_edited.csv')
targets = np.loadtxt('../data/Cleaned/targets.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-e90cd876b0e8> in <module>
#       1 features = pandas.read_csv('../data/Cleaned/features_edited.csv')
# ----> 2 targets = np.loadtxt('../data/Cleaned/targets.csv')
#
# ~/.local/share/virtualenvs/project3-robertson_blanpied-2P3Luf0-/lib/python3.7/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#    1144         # converting the data
#    1145         X = None
# -> 1146         for x in read_data(_loadtxt_chunksize):
#    1147             if X is None:
#    1148                 X = np.array(x, dtype)
#
# ~/.local/share/virtualenvs/project3-robertson_blanpied-2P3Luf0-/lib/python3.7/site-packages/numpy/lib/npyio.py in read_data(chunk_size)
#    1072
#    1073             # Convert each value according to its column and store
# -> 1074             items = [conv(val) for (conv, val) in zip(converters, vals)]
#    1075
#    1076             # Then pack it according to the dtype's nesting
#
# ~/.local/share/virtualenvs/project3-robertson_blanpied-2P3Luf0-/lib/python3.7/site-packages/numpy/lib/npyio.py in <listcomp>(.0)
#    1072
#    1073             # Convert each value according to its column and store
# -> 1074             items = [conv(val) for (conv, val) in zip(converters, vals)]
#    1075
#    1076             # Then pack it according to the dtype's nesting
#
# ~/.local/share/virtualenvs/project3-robertson_blanpied-2P3Luf0-/lib/python3.7/site-packages/numpy/lib/npyio.py in floatconv(x)
#     779         if '0x' in x:
#     780             return float.fromhex(x)
# --> 781         return float(x)
#     782
#     783     typ = dtype.type
#
# ValueError: could not convert string to float: '"BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC","BIC ...

# %%
def split(data):
    """
    returns a train, validate, and test dictionary
    """
    split_dict = {}
    split_dict.update({'train': data[0:int(len(data) * 0.8)]})
    split_dict.update({'validate': data[int(len(data) * 0.8):int(len(data) * 0.95)]})
    split_dict.update({'test': data[int(len(data) * 0.95)::]})
    return split_dict

# %%
features_scaled = preprocessing.scale(features)

features_dict = split(features)
targets_dict = split(targets)
# Out:
# Empty DataFrame
# Columns: [BIC, BIC.1, BIC.2, BIC.3, BIC.4, BIC.5, BIC.6, BIC.7, BIC.8, BIC.9, BIC.10, BIC.11, BIC.12, BIC.13, BIC.14, BIC.15, BIC.16, BIC.17, BIC.18, BIC.19, BIC.20, BIC.21, BIC.22, BIC.23, BIC.24, BIC.25, BIC.26, BIC.27, BIC.28, BIC.29, BIC.30, BIC.31, BIC.32, BIC.33, BIC.34, BIC.35, BIC.36, BIC.37, BIC.38, BIC.39, BIC.40, BIC.41, BIC.42, BIC.43, BIC.44, BIC.45, BIC.46, BIC.47, BIC.48, BIC.49, BIC.50, BIC.51, BIC.52, BIC.53, BIC.54, BIC.55, BIC.56, BIC.57, BIC.58, BIC.59, BIC.60, BIC.61, BIC.62, BIC.63, BIC.64, BIC.65, BIC.66, BIC.67, BIC.68, BIC.69, BIC.70, BIC.71, BIC.72, BIC.73, BIC.74, BIC.75, BIC.76, BIC.77, BIC.78, BIC.79, BIC.80, BIC.81, BIC.82, BIC.83, BIC.84, BIC.85, BIC.86, BIC.87, BIC.88, BIC.89, BIC.90, BIC.91, BIC.92, BIC.93, BIC.94, BIC.95, BIC.96, BIC.97, BIC.98, BIC.99, ...]
# Index: []
#
# [0 rows x 2895 columns]

# %%
print('making classifiers')
#targets_columns = targets_dict['train'].columns
classifier1 = DecisionTreeClassifier(criterion = "entropy", max_depth = 10)
classifier2 = LogisticRegression(solver = 'lbfgs', max_iter = 100)
start = time.time()
print('fitting data')

classifier1 = classifier1.fit(features, targets_columns)

print("Done in {0:03.2f} seconds".format((time.time()-start)/60))
# Out:
# making classifiers
# fitting data
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-35e30c0cb443> in <module>
#       6 print('fitting data')
#       7
# ----> 8 classifier1 = classifier1.fit(features, targets_columns)
#       9
#      10 print("Done in {0:03.2f} seconds".format((time.time()-start)/60))
#
# NameError: name 'targets_columns' is not defined
